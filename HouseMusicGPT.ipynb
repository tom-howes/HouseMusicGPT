# %% [markdown]
# <a href="https://colab.research.google.com/github/tom-howes/HouseMusicGPT/blob/main/HouseMusicGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git config --global user.name "tom-howes"
# !git config --global user.email "thomas.howes01@gmail.com"

# %%
# %cd /content/HouseMusicGPT/
# Out:
# /content/HouseMusicGPT

# %%
# !git status
# Out:
# On branch main
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !pip install miditok>=3.0.0 symusic torch tqdm matplotlib

# %%
# !mkdir -p dance_midi

# %% [markdown]
# ## MIDI File Exploratory Analysis

# %%
from pathlib import Path
from symusic import Score

midi_files = list(Path('dance_midi').glob('*.mid')) + list(Path('dance_midi').glob('*.midi'))
print(f"Found {len(midi_files)} MIDI files\n")

# Analyze a few
total_bpm = 0
for midi_path in midi_files:
    try:
        score = Score(str(midi_path))
        print(f"{midi_path.name}")
        print(f"  Duration: {score.end() / score.ticks_per_quarter / 4:.1f} bars (assuming 4/4) BPM: ", score.tempos[0].qpm)
        print(f"  Tracks: {len(score.tracks)}")
        for track in score.tracks:
            print(f"    - {track.name or 'Unnamed'}: {len(track.notes)} notes, program {track.program}")
        print()
        if score.tempos[0].qpm < 50 or score.tempos[0].qpm > 150:
          total_bpm += 120
        else:
          total_bpm += score.tempos[0].qpm
    except Exception as e:
        print(f"{midi_path.name}: Error - {e}\n")


print(total_bpm / 38)
# Out:
# Found 38 MIDI files
#
# RockDj.mid
#   Duration: 102.9 bars (assuming 4/4) BPM:  103.00163944276113
#   Tracks: 19
#     - CH0171: 246 notes, program 48
#     - CH0171: 441 notes, program 33
#     - CH0171: 432 notes, program 1
#     - CH0171: 448 notes, program 65
#     - CH0171: 363 notes, program 52
#     - CH0171: 312 notes, program 81
#     - CH0171: 30 notes, program 30
#     - CH0171: 106 notes, program 59
#     - CH0171: 14 notes, program 69
#     - CH0171: 3 notes, program 122
#     - CH0171: 909 notes, program 17
#     - CH0171: 1432 notes, program 27
#     - CH0171: 1832 notes, program 0
#     - CH0171: 1127 notes, program 48
#     - CH0171: 2392 notes, program 48
#     - CH0171: 1284 notes, program 28
#     - CH0171: 960 notes, program 27
#     - CH0171: 1408 notes, program 1
#     - CH0171: 206 notes, program 0
#
# Rose_Royce_-_Car_Wash.mid
#   Duration: 111.4 bars (assuming 4/4) BPM:  113.99995440001824
#   Tracks: 15
#     - Drums: 1425 notes, program 0
#     - Perc: 273 notes, program 0
#     - Bass Gtr: 637 notes, program 0
#     - Ac.Piano: 231 notes, program 0
#     - Jazz Gtr: 523 notes, program 0
#     - NylonGtr: 584 notes, program 0
#     - Mute Gtr: 714 notes, program 0
#     - Wha Gtr: 1376 notes, program 0
#     - El.Piano: 87 notes, program 0
#     - String 1: 270 notes, program 0
#     - String 2: 218 notes, program 0
#     - Brass: 220 notes, program 0
#     - Flt/Picc: 270 notes, program 0
#     - Grp Boy: 268 notes, program 0
#     - Lead Vox: 335 notes, program 66
#
# Hot_Chocolate_-_You_Sexy_Thing.mid
#   Duration: 80.0 bars (assuming 4/4) BPM:  107.0001266168165
#   Tracks: 9
#     - drums: 2208 notes, program 0
#     - piano: 494 notes, program 0
#     - base: 566 notes, program 34
#     - guitar: 215 notes, program 30
#     - strings: 284 notes, program 49
#     - strings2: 297 notes, program 50
#     - woodblock: 624 notes, program 115
#     - Vocals 1: 303 notes, program 80
#     - Vocals 2: 291 notes, program 88
#
# Wild_Cherry_-_Play_That_Funky_Music.mid
#   Duration: 133.0 bars (assuming 4/4) BPM:  111.000111000111
#   Tracks: 10
#     - Track 2: 892 notes, program 33
#     - Track 3: 1099 notes, program 36
#     - Track 4: 1099 notes, program 27
#     - Track 5: 132 notes, program 61
#     - Track 6: 453 notes, program 66
#     - Track 7: 67 notes, program 29
#     - Track 8: 67 notes, program 30
#     - Track 9: 67 notes, program 25
#     - Track 10: 1932 notes, program 0
#     - Track 11: 915 notes, program 26
#
# Kool_and_the_Gang_-_Ladies_Night.mid
#   Duration: 144.0 bars (assuming 4/4) BPM:  112.00005973336519
#   Tracks: 8
#     - Unnamed: 2350 notes, program 0
#     - Unnamed: 394 notes, program 3
#     - Unnamed: 769 notes, program 33
#     - Unnamed: 3313 notes, program 4
#     - Unnamed: 7 notes, program 48
#     - Unnamed: 486 notes, program 61
#     - Unnamed: 1285 notes, program 27
#     - Unnamed: 553 notes, program 66
#
# DontYouWantMe.mid
#   Duration: 237.8 bars (assuming 4/4) BPM:  234.000234000234
#   Tracks: 17
#     - Synth Bass 2: 720 notes, program 39
#     - Pad 3 (polysynth): 94 notes, program 90
#     - Synth Brass 1  Lo: 404 notes, program 62
#     - Synth Brass 1 Hi: 404 notes, program 62
#     - Synth Strings 1: 35 notes, program 50
#     - FX 4 (atmosphere): 196 notes, program 99
#     - Lead 6 (voice): 353 notes, program 85
#     - Lead 6 (voice) : 215 notes, program 85
#     - Pad 3 (polysynth): 288 notes, program 90
#     - Acoustic Snare: 296 notes, program 0
#     - Closed High Hat: 1880 notes, program 0
#     - Crash Cymbal 1: 1 notes, program 0
#     - Bass Drum: 347 notes, program 0
#     - Synth Brass 1: 91 notes, program 62
#     - Synth Brass 1: 1280 notes, program 62
#     - Synth Brass 1: 368 notes, program 62
#     - Synth Brass 1: 1244 notes, program 62
#
# TaintedLove.mid
#   Duration: 114.4 bars (assuming 4/4) BPM:  148.0019733596448
#   Tracks: 14
#     - profilemid: 416 notes, program 32
#     - Organ bas: 416 notes, program 16
#     - horn blas: 138 notes, program 61
#     - bell     : 32 notes, program 88
#     - high stri: 16 notes, program 95
#     - Farfisa  : 306 notes, program 17
#     - choir    : 58 notes, program 52
#     - vocal mel: 305 notes, program 53
#     - vocal har: 88 notes, program 53
#     - kick     : 446 notes, program 0
#     - snare (sn: 256 notes, program 0
#     - HI Q 27  : 12 notes, program 0
#     - NOISE SLA: 84 notes, program 0
#     - CLAPS 39 : 84 notes, program 0
#
# NaturalBlues.mid
#   Duration: 114.0 bars (assuming 4/4) BPM:  108.000108000108
#   Tracks: 8
#     - Unnamed: 501 notes, program 33
#     - Unnamed: 56 notes, program 50
#     - Unnamed: 479 notes, program 42
#     - Unnamed: 9 notes, program 54
#     - Unnamed: 120 notes, program 79
#     - Unnamed: 719 notes, program 0
#     - Unnamed: 4676 notes, program 0
#     - Unnamed: 0 notes, program 0
#
# Mustang Sally.mid
#   Duration: 19.0 bars (assuming 4/4) BPM:  155.00031000062
#   Tracks: 7
#     - (C) HitTrax: Mustang Sally: 37 notes, program 3
#     - (C) HitTrax: Mustang Sally: 75 notes, program 33
#     - (C) HitTrax: Mustang Sally: 130 notes, program 30
#     - (C) HitTrax: Mustang Sally: 31 notes, program 66
#     - (C) HitTrax: Mustang Sally: 28 notes, program 17
#     - (C) HitTrax: Mustang Sally: 367 notes, program 0
#     - (C) HitTrax: Mustang Sally: 16 notes, program 67
#
# CantGetYououtofMyHead(3).mid
#   Duration: 121.0 bars (assuming 4/4) BPM:  125.0
#   Tracks: 11
#     - drummix: 0 notes, program 0
#     - drummix: 2858 notes, program 25
#     - Untitled: 174 notes, program 120
#     - SynthBass2: 427 notes, program 39
#     - Organ 2: 424 notes, program 17
#     - Vocal: 391 notes, program 82
#     - backvocals: 265 notes, program 91
#     - Bass&Lead: 214 notes, program 87
#     - E.Piano 1: 338 notes, program 4
#     - Strings: 92 notes, program 48
#     - Polysynth: 17 notes, program 90
#
# keep it comin love.mid
#   Duration: 26.0 bars (assuming 4/4) BPM:  150.0
#   Tracks: 13
#     - KEEP IT COMIN' LOVE: 304 notes, program 0
#     - KEEP IT COMIN' LOVE: 164 notes, program 33
#     - KEEP IT COMIN' LOVE: 320 notes, program 27
#     - KEEP IT COMIN' LOVE: 71 notes, program 66
#     - KEEP IT COMIN' LOVE: 68 notes, program 54
#     - KEEP IT COMIN' LOVE: 66 notes, program 56
#     - KEEP IT COMIN' LOVE: 66 notes, program 65
#     - KEEP IT COMIN' LOVE: 66 notes, program 66
#     - KEEP IT COMIN' LOVE: 66 notes, program 57
#     - KEEP IT COMIN' LOVE: 655 notes, program 0
#     - KEEP IT COMIN' LOVE: 66 notes, program 67
#     - KEEP IT COMIN' LOVE: 66 notes, program 61
#     - KEEP IT COMIN' LOVE: 50 notes, program 1
#
# Rick_James_-_Super_Freak.mid
#   Duration: 111.0 bars (assuming 4/4) BPM:  132.000132000132
#   Tracks: 7
#     - bass: 414 notes, program 33
#     - E Pno: 828 notes, program 3
#     - Lead synth: 46 notes, program 90
#     - Synth2: 72 notes, program 81
#     - Mute Guitar: 100 notes, program 28
#     - Guitar: 424 notes, program 27
#     - Drums: 1400 notes, program 0
#
# Kiki_Dee_-_I've_Got_the_Music_in_Me.mid
#   Duration: 118.2 bars (assuming 4/4) BPM:  122.0000691333725
#   Tracks: 12
#     - Melody: 503 notes, program 60
#     - Vocals: 46 notes, program 82
#     - Bass: 642 notes, program 33
#     - Keyboard 1: 1251 notes, program 1
#     - Keyboard 2: 381 notes, program 5
#     - Keyboard 3: 154 notes, program 18
#     - Guitar 1: 191 notes, program 29
#     - Guitar 2: 244 notes, program 27
#     - Strings: 216 notes, program 48
#     - Drums: 1879 notes, program 0
#     - Brass: 131 notes, program 61
#     - Trombone: 140 notes, program 57
#
# Donna_Summer_-_I_Feel_Love.mid
#   Duration: 197.0 bars (assuming 4/4) BPM:  130.00013000013
#   Tracks: 11
#     - Unnamed: 557 notes, program 99
#     - Unnamed: 195 notes, program 50
#     - Unnamed: 3 notes, program 97
#     - Unnamed: 1623 notes, program 38
#     - Unnamed: 1560 notes, program 38
#     - Unnamed: 342 notes, program 43
#     - Unnamed: 2686 notes, program 0
#     - Unnamed: 678 notes, program 0
#     - Unnamed: 1358 notes, program 0
#     - Unnamed: 348 notes, program 0
#     - Unnamed: 780 notes, program 24
#
# David_Bowie_-_Let's_Dance.mid
#   Duration: 121.5 bars (assuming 4/4) BPM:  113.00009605008164
#   Tracks: 12
#     - Unnamed: 532 notes, program 38
#     - Unnamed: 208 notes, program 17
#     - Unnamed: 895 notes, program 26
#     - Unnamed: 558 notes, program 26
#     - Unnamed: 63 notes, program 29
#     - Unnamed: 368 notes, program 61
#     - Unnamed: 555 notes, program 65
#     - Unnamed: 368 notes, program 66
#     - Unnamed: 1690 notes, program 16
#     - Unnamed: 252 notes, program 115
#     - Unnamed: 94 notes, program 53
#     - Unnamed: 186 notes, program 66
#
# Frankie_Goes_to_Hollywood_-_Relax.mid
#   Duration: 110.0 bars (assuming 4/4) BPM:  122.00180562672328
#   Tracks: 20
#     - BASS: 724 notes, program 36
#     - SYNTH: 138 notes, program 50
#     - MELODY: 281 notes, program 81
#     - SYNTH STA: 821 notes, program 62
#     - BRASS STA: 383 notes, program 61
#     - STRINGS: 478 notes, program 48
#     - PAD: 67 notes, program 52
#     - SQUARE SY: 280 notes, program 80
#     - DRUMS: 1849 notes, program 16
#     - SFX: 1 notes, program 24
#     - SFX: 1 notes, program 25
#     - SFX: 9 notes, program 29
#     - SFX: 1 notes, program 122
#     - SFX: 1 notes, program 126
#     - GUITAR CL: 116 notes, program 37
#     - WOW SYNTH: 18 notes, program 95
#     - SYNTH: 116 notes, program 87
#     - SYNTH: 3 notes, program 109
#     - HARMONIC: 30 notes, program 31
#     - GUITAR DI: 78 notes, program 30
#
# Kool_and_the_Gang_-_Get_Down_On_It.mid
#   Duration: 126.4 bars (assuming 4/4) BPM:  108.99994368336243
#   Tracks: 9
#     - tk1: 1113 notes, program 5
#     - tk2: 340 notes, program 33
#     - tk3: 2746 notes, program 27
#     - tk4: 654 notes, program 53
#     - tk5: 105 notes, program 61
#     - tk6: 135 notes, program 65
#     - tk7: 1565 notes, program 62
#     - tk8: 696 notes, program 28
#     - tk10: 2017 notes, program 0
#
# Im a believer.mid
#   Duration: 23.8 bars (assuming 4/4) BPM:  163.00007063336395
#   Tracks: 6
#     - AP1067:  I'm A Believer: 255 notes, program 25
#     - AP1067:  I'm A Believer: 120 notes, program 33
#     - AP1067:  I'm A Believer: 39 notes, program 16
#     - AP1067:  I'm A Believer: 110 notes, program 27
#     - AP1067:  I'm A Believer: 9 notes, program 48
#     - AP1067:  I'm A Believer: 341 notes, program 0
#
# KC_and_The_Sunshine_Band_-_KC_Medley.mid
#   Duration: 117.3 bars (assuming 4/4) BPM:  112.00089600716805
#   Tracks: 12
#     - Melody: 426 notes, program 65
#     - Choir: 372 notes, program 52
#     - Piano: 1282 notes, program 1
#     - Rhodes: 111 notes, program 5
#     - Guitar: 1235 notes, program 28
#     - Strings: 158 notes, program 49
#     - Brass: 717 notes, program 61
#     - Synthbass: 684 notes, program 39
#     - Rev Cymbal: 1 notes, program 119
#     - Gunshot: 1 notes, program 127
#     - Seashore: 1 notes, program 122
#     - Drums: 5455 notes, program 0
#
# Kool_and_the_Gang_-_Jungle_Boogie.mid
#   Duration: 48.5 bars (assuming 4/4) BPM:  100.0
#   Tracks: 8
#     - Trumpet: 243 notes, program 56
#     - Alto Sax: 270 notes, program 65
#     - Tenor Sax: 231 notes, program 66
#     - Fingered Bass: 208 notes, program 33
#     - Percussion: 673 notes, program 0
#     - Synth Bass 2: 208 notes, program 39
#     - Clean Elec. Guitar: 576 notes, program 27
#     - Voice Oohs: 220 notes, program 53
#
# KC_and_The_Sunshine_Band_-_I'm_Your_Boogie_Man.mid
#   Duration: 146.7 bars (assuming 4/4) BPM:  122.0000691333725
#   Tracks: 8
#     - Unnamed: 1714 notes, program 0
#     - Unnamed: 646 notes, program 33
#     - Unnamed: 100 notes, program 27
#     - Unnamed: 468 notes, program 5
#     - Unnamed: 1469 notes, program 61
#     - Unnamed: 4007 notes, program 0
#     - Unnamed: 506 notes, program 66
#     - Unnamed: 3694 notes, program 27
#
# Darude_-_Sandstorm.mid
#   Duration: 140.8 bars (assuming 4/4) BPM:  100.0
#   Tracks: 12
#     - Unnamed: 12 notes, program 119
#     - Unnamed: 9 notes, program 122
#     - Unnamed: 10 notes, program 127
#     - Unnamed: 2 notes, program 50
#     - Unnamed: 192 notes, program 87
#     - Unnamed: 4881 notes, program 90
#     - Unnamed: 2662 notes, program 80
#     - Unnamed: 1331 notes, program 109
#     - Unnamed: 340 notes, program 26
#     - Unnamed: 1874 notes, program 0
#     - Unnamed: 1176 notes, program 87
#     - Unnamed: 60 notes, program 123
#
# Venga_Boys_-_Boom_Boom_Boom_Boom.mid
#   Duration: 118.7 bars (assuming 4/4) BPM:  138.00019320027047
#   Tracks: 14
#     - Boom Boom Boom Boom: 786 notes, program 16
#     - By: The Vengaboys: 10 notes, program 48
#     - Unnamed: 365 notes, program 71
#     - Sequenced by:: 1442 notes, program 87
#     - TOP LIST SEQUENCING TEAM: 87 notes, program 113
#     - JC & JOEROCK !!: 7 notes, program 119
#     - Unnamed: 3 notes, program 122
#     - Exclusively for:: 721 notes, program 63
#     - Top List Midi Files and The Dance Midi House: 4032 notes, program 16
#     - http://www.netexplorers.com/member/midizone/: 4 notes, program 118
#     - http://www.exrock.com: 694 notes, program 81
#     - Unnamed: 347 notes, program 79
#     - Email us: midizone@technologist.com: 178 notes, program 82
#     - Unnamed: 393 notes, program 17
#
# Alice_Deejay_-_Better_Off_Alone.mid
#   Duration: 121.5 bars (assuming 4/4) BPM:  136.0001450668214
#   Tracks: 14
#     - Lead Right: 429 notes, program 81
#     - Bass: 352 notes, program 32
#     - BD use your own sample : 702 notes, program 25
#     - Drums: 1465 notes, program 25
#     - Aah: 15 notes, program 52
#     - Bass String: 15 notes, program 49
#     - String: 15 notes, program 48
#     - Bass Lead Left: 704 notes, program 80
#     - Voice: 177 notes, program 53
#     - Atmosphere/Brightness You choose: 377 notes, program 99
#     - Snare: 432 notes, program 25
#     - If you can do this noise please inform me: 71 notes, program 120
#     - Bass Lead Right: 704 notes, program 80
#     - Lead Left: 429 notes, program 81
#
# faith.mid
#   Duration: 27.0 bars (assuming 4/4) BPM:  158.0003476007647
#   Tracks: 16
#     - Faith: 52 notes, program 0
#     - Faith: 133 notes, program 32
#     - Faith: 132 notes, program 26
#     - Faith: 99 notes, program 66
#     - Faith: 90 notes, program 54
#     - Faith: 18 notes, program 53
#     - Faith: 52 notes, program 12
#     - Faith: 48 notes, program 56
#     - Faith: 16 notes, program 61
#     - Faith: 362 notes, program 0
#     - Faith: 32 notes, program 65
#     - Faith: 16 notes, program 66
#     - Faith: 28 notes, program 27
#     - Faith: 466 notes, program 0
#     - Faith: 40 notes, program 67
#     - Faith: 75 notes, program 1
#
# fallinlove2nite.mid
#   Duration: 24.0 bars (assuming 4/4) BPM:  100.0
#   Tracks: 11
#     - untitled: 184 notes, program 34
#     - untitled: 280 notes, program 76
#     - untitled: 75 notes, program 65
#     - untitled: 29 notes, program 4
#     - untitled: 50 notes, program 56
#     - untitled: 6 notes, program 48
#     - untitled: 36 notes, program 61
#     - untitled: 234 notes, program 24
#     - untitled: 420 notes, program 99
#     - untitled: 112 notes, program 39
#     - untitled: 69 notes, program 0
#
# Michael_Jackson_-_Thriller.mid
#   Duration: 162.1 bars (assuming 4/4) BPM:  120.0
#   Tracks: 14
#     - Synth Bass 2: 880 notes, program 39
#     - Pad 3 (polysynth): 395 notes, program 90
#     - Shanai Percussive: 486 notes, program 111
#     - Electric Guitar (muted): 1276 notes, program 28
#     - Voice Oohs: 277 notes, program 53
#     - Brass Section: 339 notes, program 61
#     - Whistle: 120 notes, program 78
#     - Church Organ: 134 notes, program 19
#     - Unnamed: 3600 notes, program 0
#     - Acoustic Guitar (steel): 118 notes, program 25
#     - Electric Piano 2: 29 notes, program 5
#     - Shamisen: 178 notes, program 106
#     - Lead 8 (bass + lead): 196 notes, program 87
#     - Electric Bass (finger): 341 notes, program 33
#
# Lipps_Inc_-_Funkytown.mid
#   Duration: 173.9 bars (assuming 4/4) BPM:  122.99996925000768
#   Tracks: 17
#     - Vocoder: 50 notes, program 54
#     - Bass: 1251 notes, program 87
#     - Strings: 72 notes, program 48
#     - Lead #1: 180 notes, program 81
#     - Sax Solo: 34 notes, program 65
#     - Sax Solo: 34 notes, program 64
#     - Gitar: 458 notes, program 27
#     - Reverse Cymbal: 2 notes, program 119
#     - Bass Drum & Snare: 704 notes, program 25
#     - Hi-Hat: 1225 notes, program 0
#     - Wood Blocks: 1232 notes, program 0
#     - Cow Bell: 525 notes, program 0
#     - Hi Q: 86 notes, program 0
#     - Crash Cymbal: 13 notes, program 0
#     - Shaker: 1239 notes, program 0
#     - Side Stick: 309 notes, program 0
#     - Claps: 54 notes, program 0
#
# People on the high line.mid
#   Duration: 22.5 bars (assuming 4/4) BPM:  120.0
#   Tracks: 6
#     - Piano: 229 notes, program 0
#     - Bass: 191 notes, program 33
#     - Strings: 73 notes, program 48
#     - Brightness: 56 notes, program 100
#     - Bass & Lead: 29 notes, program 87
#     - Drums: 457 notes, program 0
#
# C+C_Dance_Factory_-_Gonna'_Make_You_Sweat.mid
#   Duration: 117.0 bars (assuming 4/4) BPM:  114.0001710002565
#   Tracks: 15
#     - Unnamed: 954 notes, program 30
#     - Unnamed: 359 notes, program 115
#     - Unnamed: 323 notes, program 61
#     - Unnamed: 390 notes, program 81
#     - Unnamed: 142 notes, program 66
#     - Unnamed: 46 notes, program 50
#     - Unnamed: 1116 notes, program 17
#     - Unnamed: 96 notes, program 117
#     - Unnamed: 111 notes, program 119
#     - Unnamed: 380 notes, program 25
#     - Unnamed: 42 notes, program 58
#     - Unnamed: 2403 notes, program 25
#     - Unnamed: 317 notes, program 34
#     - Unnamed: 32 notes, program 39
#     - Unnamed: 329 notes, program 3
#
# New_Order_-_Blue_Monday.mid
#   Duration: 253.0 bars (assuming 4/4) BPM:  132.9999468000213
#   Tracks: 20
#     - Unnamed: 1170 notes, program 0
#     - Unnamed: 20 notes, program 0
#     - Unnamed: 1599 notes, program 0
#     - Unnamed: 516 notes, program 0
#     - Unnamed: 735 notes, program 0
#     - Unnamed: 8 notes, program 0
#     - Unnamed: 305 notes, program 0
#     - Unnamed: 10 notes, program 0
#     - Unnamed: 3 notes, program 16
#     - Unnamed: 354 notes, program 28
#     - Unnamed: 510 notes, program 28
#     - Unnamed: 192 notes, program 38
#     - Unnamed: 816 notes, program 39
#     - Unnamed: 1080 notes, program 38
#     - Unnamed: 488 notes, program 27
#     - Unnamed: 4 notes, program 52
#     - Unnamed: 123 notes, program 50
#     - Unnamed: 91 notes, program 48
#     - Unnamed: 219 notes, program 85
#     - Unnamed: 116 notes, program 48
#
# la bamba.mid
#   Duration: 22.1 bars (assuming 4/4) BPM:  152.00032426735845
#   Tracks: 6
#     - LA BAMBA: 119 notes, program 0
#     - LA BAMBA: 77 notes, program 33
#     - LA BAMBA: 121 notes, program 27
#     - LA BAMBA: 16 notes, program 27
#     - LA BAMBA: 8 notes, program 21
#     - LA BAMBA: 491 notes, program 0
#
# YouSpinMeRound.mid
#   Duration: 136.0 bars (assuming 4/4) BPM:  135.000135000135
#   Tracks: 9
#     - Unnamed: 1752 notes, program 62
#     - Unnamed: 4173 notes, program 0
#     - Unnamed: 1075 notes, program 39
#     - Unnamed: 972 notes, program 36
#     - Unnamed: 216 notes, program 90
#     - Unnamed: 1423 notes, program 11
#     - Unnamed: 1421 notes, program 11
#     - Unnamed: 1066 notes, program 8
#     - Unnamed: 360 notes, program 5
#
# KC_and_The_Sunshine_Band_-_That's_the_Way_I_Like_It.mid
#   Duration: 90.5 bars (assuming 4/4) BPM:  110.00011000011
#   Tracks: 12
#     - PIANO: 1827 notes, program 0
#     - CLAV: 603 notes, program 7
#     - GUITAR: 2649 notes, program 27
#     - TRUMPET 1: 559 notes, program 56
#     - TRUMPET 2: 441 notes, program 61
#     - SAX: 125 notes, program 66
#     - TROMBONE: 125 notes, program 57
#     - BARI SAX: 49 notes, program 67
#     - BASS: 565 notes, program 35
#     - DRUMS: 1834 notes, program 0
#     - PERC: 745 notes, program 0
#     - TOMS: 16 notes, program 117
#
# AroundTheWorld.mid
#   Duration: 80.2 bars (assuming 4/4) BPM:  120.0
#   Tracks: 6
#     - synth 1: 248 notes, program 80
#     - synth 2: 258 notes, program 36
#     - synth 3: 432 notes, program 35
#     - synth 4: 560 notes, program 81
#     - synth 5: 30 notes, program 62
#     - percussion: 1138 notes, program 0
#
# SexyBitch.mid
#   Duration: 105.0 bars (assuming 4/4) BPM:  130.00013000013
#   Tracks: 10
#     - Hollow mini: 288 notes, program 80
#     - Basse: 379 notes, program 39
#     - LA Saw: 759 notes, program 81
#     - Chant: 427 notes, program 73
#     - Chant: 0 notes, program 0
#     - Choeurs: 78 notes, program 82
#     - Wind: 1 notes, program 122
#     - Rev: 3 notes, program 119
#     - SynDrum: 20 notes, program 118
#     - Drums: 1223 notes, program 0
#
# GetluckyfeatPharrellWilliams.mid
#   Duration: 121.0 bars (assuming 4/4) BPM:  120.0
#   Tracks: 10
#     - untitled: 794 notes, program 33
#     - untitled: 809 notes, program 33
#     - untitled: 277 notes, program 5
#     - untitled: 389 notes, program 0
#     - untitled: 3309 notes, program 27
#     - untitled: 1977 notes, program 0
#     - untitled: 216 notes, program 7
#     - untitled: 347 notes, program 7
#     - untitled: 48 notes, program 35
#     - untitled: 493 notes, program 65
#
# Gloria_Gaynor_-_I_Will_Survive.mid
#   Duration: 144.3 bars (assuming 4/4) BPM:  115.00002875000719
#   Tracks: 10
#     - Melody: 578 notes, program 65
#     - Piano: 1342 notes, program 0
#     - Brass: 500 notes, program 61
#     - Guitar: 2715 notes, program 45
#     - Brass: 72 notes, program 61
#     - Strings: 982 notes, program 48
#     - Strings : 281 notes, program 48
#     - Harp: 164 notes, program 46
#     - Bass: 767 notes, program 34
#     - Drums: 3159 notes, program 0
#
# 119.84231429618232

# %%
print(f"{'File':<45} {'BPM':<10} {'Likely Actual BPM'}")
print("-" * 70)

tempos = []

for midi_path in midi_files:
    try:
        score = Score(str(midi_path))

        if score.tempos:
            bpm = score.tempos[0].qpm
        else:
            bpm = 120

        # Flag likely errors and suggest fix
        if bpm > 160:
            likely_bpm = bpm / 2
            flag = f"← probably {likely_bpm:.0f}"
        elif bpm < 80:
            likely_bpm = bpm * 2
            flag = f"← probably {likely_bpm:.0f}"
        else:
            likely_bpm = bpm
            flag = ""

        tempos.append(likely_bpm)
        print(f"{midi_path.name:<45} {bpm:<10.1f} {flag}")

    except Exception as e:
        print(f"{midi_path.name:<45} Error: {e}")

print(f"\n--- Summary ---")
print(f"Tempo range (corrected): {min(tempos):.0f} - {max(tempos):.0f} BPM")
print(f"Average: {sum(tempos)/len(tempos):.0f} BPM")
# Out:
# File                                          BPM        Likely Actual BPM
# ----------------------------------------------------------------------
# RockDj.mid                                    103.0
# Rose_Royce_-_Car_Wash.mid                     114.0
# Hot_Chocolate_-_You_Sexy_Thing.mid            107.0
# Wild_Cherry_-_Play_That_Funky_Music.mid       111.0
# Kool_and_the_Gang_-_Ladies_Night.mid          112.0
# DontYouWantMe.mid                             234.0      ← probably 117
# TaintedLove.mid                               148.0
# NaturalBlues.mid                              108.0
# Mustang Sally.mid                             155.0
# CantGetYououtofMyHead(3).mid                  125.0
# keep it comin love.mid                        150.0
# Rick_James_-_Super_Freak.mid                  132.0
# Kiki_Dee_-_I've_Got_the_Music_in_Me.mid       122.0
# Donna_Summer_-_I_Feel_Love.mid                130.0
# David_Bowie_-_Let's_Dance.mid                 113.0
# Frankie_Goes_to_Hollywood_-_Relax.mid         122.0
# Kool_and_the_Gang_-_Get_Down_On_It.mid        109.0
# Im a believer.mid                             163.0      ← probably 82
# KC_and_The_Sunshine_Band_-_KC_Medley.mid      112.0
# Kool_and_the_Gang_-_Jungle_Boogie.mid         100.0
# KC_and_The_Sunshine_Band_-_I'm_Your_Boogie_Man.mid 122.0
# Darude_-_Sandstorm.mid                        100.0
# Venga_Boys_-_Boom_Boom_Boom_Boom.mid          138.0
# Alice_Deejay_-_Better_Off_Alone.mid           136.0
# faith.mid                                     158.0
# fallinlove2nite.mid                           100.0
# Michael_Jackson_-_Thriller.mid                120.0
# Lipps_Inc_-_Funkytown.mid                     123.0
# People on the high line.mid                   120.0
# C+C_Dance_Factory_-_Gonna'_Make_You_Sweat.mid 114.0
# New_Order_-_Blue_Monday.mid                   133.0
# la bamba.mid                                  152.0
# YouSpinMeRound.mid                            135.0
# KC_and_The_Sunshine_Band_-_That's_the_Way_I_Like_It.mid 110.0
# AroundTheWorld.mid                            120.0
# SexyBitch.mid                                 130.0
# GetluckyfeatPharrellWilliams.mid              120.0
# Gloria_Gaynor_-_I_Will_Survive.mid            115.0
#
# --- Summary ---
# Tempo range (corrected): 82 - 158 BPM
# Average: 122 BPM

# %% [markdown]
# ## Tokenization

# %%
from miditok import REMI, TokenizerConfig
from symusic import Score
from pathlib import Path

# Configure tokenizer for dance music
config = TokenizerConfig(
    num_velocities=16,          # Quantize velocity into 16 bins
    use_chords=False,                    # Enable chord detection
    # chord_tokens_with_root_note=True,    # Include root note (e.g. "Chord_C:maj")
    use_programs=True,                  # Enable multi-instrument
    use_time_signatures=True,
    use_tempos=True,                    # Allows model to predict changes in tempo
    num_tempos=32,                      # Number of tempo bins
    tempo_range=(100, 140),             # Dance music tempo range
    one_token_stream_for_programs=True,  # Prepend instrument to Pitch, NoteOn, NoteOff (test with initially - might set to false to generate individual instruments if I run into issues)
    beat_res={(0, 4): 8, (4, 12): 4},
)

tokenizer = REMI(config)

print("Vocabulary size:", len(tokenizer))
print("\nSample tokens from vocabulary:")
for i, token in enumerate(tokenizer.vocab):
    print(f"  {i}: {token}")
    if i > 30:
        print("  ...")
        break
# Out:
# Vocabulary size: 502
#
# Sample tokens from vocabulary:
#   0: PAD_None
#   1: BOS_None
#   2: EOS_None
#   3: MASK_None
#   4: Bar_None
#   5: Pitch_21
#   6: Pitch_22
#   7: Pitch_23
#   8: Pitch_24
#   9: Pitch_25
#   10: Pitch_26
#   11: Pitch_27
#   12: Pitch_28
#   13: Pitch_29
#   14: Pitch_30
#   15: Pitch_31
#   16: Pitch_32
#   17: Pitch_33
#   18: Pitch_34
#   19: Pitch_35
#   20: Pitch_36
#   21: Pitch_37
#   22: Pitch_38
#   23: Pitch_39
#   24: Pitch_40
#   25: Pitch_41
#   26: Pitch_42
#   27: Pitch_43
#   28: Pitch_44
#   29: Pitch_45
#   30: Pitch_46
#   31: Pitch_47
#   ...
# /usr/local/lib/python3.12/dist-packages/miditok/tokenizations/remi.py:88: UserWarning: Attribute controls are not compatible with 'config.one_token_stream_for_programs' and multi-vocabulary tokenizers. Disabling them from the config.
#   super().__init__(tokenizer_config, params)

# %%
test_file = midi_files[0]

tokens = tokenizer(test_file)

print(f"File: {test_file.name}")
print(f"Total tokens: {len(tokens.ids)}")

# Find bar positions
bar_positions = [i for i, tok_id in enumerate(tokens.ids) if 'Bar' in tokenizer[tok_id]]

# Ensure bars follow song structure and tokens are evenly spread
print(f"Total bars: {len(bar_positions)}")
print(f"\nTokens per bar (first 20 bars):")
for i in range(min(20, len(bar_positions) - 1)):
    start = bar_positions[i]
    end = bar_positions[i + 1]
    print(f"  Bar {i + 1}: {end - start} tokens")

# Check that individual tokens look correct
print(f"\nFirst 100 tokens:")
for i, tok_id in enumerate(tokens.ids[:100]):
    tok = tokenizer[tok_id]
    print(f"  {i:3d}: {tok}")
# Out:
# File: RockDj.mid
# Total tokens: 57426
# Total bars: 103
#
# Tokens per bar (first 20 bars):
#   Bar 1: 4 tokens
#   Bar 2: 22 tokens
#   Bar 3: 314 tokens
#   Bar 4: 314 tokens
#   Bar 5: 314 tokens
#   Bar 6: 314 tokens
#   Bar 7: 561 tokens
#   Bar 8: 548 tokens
#   Bar 9: 561 tokens
#   Bar 10: 532 tokens
#   Bar 11: 547 tokens
#   Bar 12: 540 tokens
#   Bar 13: 557 tokens
#   Bar 14: 564 tokens
#   Bar 15: 526 tokens
#   Bar 16: 511 tokens
#   Bar 17: 523 tokens
#   Bar 18: 587 tokens
#   Bar 19: 526 tokens
#   Bar 20: 514 tokens
#
# First 100 tokens:
#     0: Bar_None
#     1: TimeSig_4/4
#     2: Position_0
#     3: Tempo_102.58
#     4: Bar_None
#     5: TimeSig_4/4
#     6: Position_0
#     7: Program_-1
#     8: PitchDrum_37
#     9: Velocity_71
#    10: Duration_0.2.8
#    11: Position_8
#    12: Program_-1
#    13: PitchDrum_37
#    14: Velocity_47
#    15: Duration_0.2.8
#    16: Position_16
#    17: Program_-1
#    18: PitchDrum_37
#    19: Velocity_47
#    20: Duration_0.2.8
#    21: Position_24
#    22: Program_-1
#    23: PitchDrum_37
#    24: Velocity_47
#    25: Duration_0.2.8
#    26: Bar_None
#    27: TimeSig_4/4
#    28: Position_0
#    29: Program_48
#    30: Pitch_57
#    31: Velocity_79
#    32: Duration_0.1.8
#    33: Program_48
#    34: Pitch_60
#    35: Velocity_79
#    36: Duration_0.1.8
#    37: Program_48
#    38: Pitch_62
#    39: Velocity_79
#    40: Duration_0.1.8
#    41: Program_48
#    42: Pitch_64
#    43: Velocity_79
#    44: Duration_0.1.8
#    45: Program_48
#    46: Pitch_50
#    47: Velocity_71
#    48: Duration_0.2.8
#    49: Program_33
#    50: Pitch_26
#    51: Velocity_127
#    52: Duration_0.4.8
#    53: Program_1
#    54: Pitch_38
#    55: Velocity_111
#    56: Duration_0.4.8
#    57: Program_1
#    58: Pitch_50
#    59: Velocity_111
#    60: Duration_0.4.8
#    61: Program_-1
#    62: PitchDrum_36
#    63: Velocity_127
#    64: Duration_0.1.8
#    65: Program_-1
#    66: PitchDrum_44
#    67: Velocity_127
#    68: Duration_0.1.8
#    69: Position_4
#    70: Program_48
#    71: Pitch_57
#    72: Velocity_79
#    73: Duration_0.1.8
#    74: Program_48
#    75: Pitch_60
#    76: Velocity_79
#    77: Duration_0.1.8
#    78: Program_48
#    79: Pitch_62
#    80: Velocity_79
#    81: Duration_0.1.8
#    82: Program_48
#    83: Pitch_64
#    84: Velocity_79
#    85: Duration_0.1.8
#    86: Program_48
#    87: Pitch_50
#    88: Velocity_71
#    89: Duration_0.2.8
#    90: Program_1
#    91: Pitch_60
#    92: Velocity_71
#    93: Duration_0.1.8
#    94: Program_1
#    95: Pitch_62
#    96: Velocity_71
#    97: Duration_0.1.8
#    98: Program_1
#    99: Pitch_64

# %%
all_tokens = []
total_tokens = 0

print(f"{'File':<60} {'Tokens':<10}")
print("-" * 70)

for midi_path in midi_files:
  try:
    tokens = tokenizer(midi_path)
    all_tokens.append(tokens)
    total_tokens += len(tokens.ids)
    print(f"{midi_path.name:<60} {len(tokens.ids):<10}")
  except Exception as e:
    print(f"{midi_path.name:<60} Error: {e}")

print("-" * 70)
print(f"{'TOTAL':<60} {total_tokens:<10}")
print(f"Files tokenized: {len(all_tokens)}")
print(f"Average tokens per song: {total_tokens / len(all_tokens)}")
print(f"Vocab size: {len(tokenizer)}")
# Out:
# File                                                         Tokens
# ----------------------------------------------------------------------
# RockDj.mid                                                   57426
# Rose_Royce_-_Car_Wash.mid                                    31590
# Hot_Chocolate_-_You_Sexy_Thing.mid                           22440
# Wild_Cherry_-_Play_That_Funky_Music.mid                      28671
# Kool_and_the_Gang_-_Ladies_Night.mid                         38592
# DontYouWantMe.mid                                            35849
# TaintedLove.mid                                              11568
# NaturalBlues.mid                                             28066
# Mustang Sally.mid                                            2987
# CantGetYououtofMyHead(3).mid                                 22211
# keep it comin love.mid                                       8500
# Rick_James_-_Super_Freak.mid                                 14168
# Kiki_Dee_-_I've_Got_the_Music_in_Me.mid                      24887
# Donna_Summer_-_I_Feel_Love.mid                               44223
# David_Bowie_-_Let's_Dance.mid                                24704
# Frankie_Goes_to_Hollywood_-_Relax.mid                        23070
# Kool_and_the_Gang_-_Get_Down_On_It.mid                       39310
# Im a believer.mid                                            3721
# KC_and_The_Sunshine_Band_-_KC_Medley.mid                     44382
# Kool_and_the_Gang_-_Jungle_Boogie.mid                        11289
# KC_and_The_Sunshine_Band_-_I'm_Your_Boogie_Man.mid           52521
# Darude_-_Sandstorm.mid                                       52539
# Venga_Boys_-_Boom_Boom_Boom_Boom.mid                         37730
# Alice_Deejay_-_Better_Off_Alone.mid                          25276
# faith.mid                                                    6910
# fallinlove2nite.mid                                          6349
# Michael_Jackson_-_Thriller.mid                               36149
# Lipps_Inc_-_Funkytown.mid                                    32641
# People on the high line.mid                                  4450
# C+C_Dance_Factory_-_Gonna'_Make_You_Sweat.mid                30128
# New_Order_-_Blue_Monday.mid                                  37023
# la bamba.mid                                                 3537
# YouSpinMeRound.mid                                           52172
# KC_and_The_Sunshine_Band_-_That's_the_Way_I_Like_It.mid      39842
# AroundTheWorld.mid                                           11562
# SexyBitch.mid                                                13884
# GetluckyfeatPharrellWilliams.mid                             36789
# Gloria_Gaynor_-_I_Will_Survive.mid                           44759
# ----------------------------------------------------------------------
# TOTAL                                                        1041915
# Files tokenized: 38
# Average tokens per song: 27418.815789473683
# Vocab size: 502
